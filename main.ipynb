# %%
print("hello")
# Out:
# hello

# %%
a = {'a', 'b', 'c'}

# %%
a = {'name' : 'A', 'age' : 18, 'sex' : 'female'}
print(a)
# Out:
# {'name': 'A', 'age': 18, 'sex': 'female'}

# %%
class Solution:
    def hasDuplicate(self, nums: List[int]) -> bool:
        mark=[0]*99999
        for i in nums:
            mark[i] +=1
        for i in mark:
            if(i > 1):
                return False
        return True

# %%
class Solution:
    def hasDuplicate(self, nums: List[int]) -> bool:
        seen=set()

        for i in nums:
            if i in seen:
                return True
            seen.add(i)
        return False

# %%
class Solution:

    def dickerize(self, s:str) -> dict:
        dick={}
        for i in s:
            if i in dick:
                dick[i]+=1
            else:
                dick[i]=0
        return dick

    def isAnagram(self, s: str, t: str) -> bool:
        dic1={}
        dic2={}
        
        dic1 = self.dickerize(s)
        dic2 = self.dickerize(t)

        if(dic1 == dic2):
            return True
        else:
            return False

# %%
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        n = len(nums)
        for i in range(n):
            for j in range(i+1,n):
                if nums[i] + nums[j] == target:
                    return [i, j]
